# %% [markdown]
# # 反爬：代理伺服器/IP
#
# * 了解「IP 黑/白名單」的反爬蟲機制
# * 「IP 黑/白名單」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 目前程式中的 proxy_ips 是手動輸入的，請根據 https://free-proxy-list.net/ 寫一個可自動化抓取可用 Proxy 的 proxy_ips。

# %%
from bs4 import BeautifulSoup
import requests
import random

# %%
proxy_ips = []

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Cafari/537.36'}
r =requests.get('https://free-proxy-list.net/',headers=headers)
soup=BeautifulSoup(r.text,'lxml')

for tr in soup.find('tbody').find_all('tr')[:100]:
    proxy=tr.find_all('td')[0].text + ':' + tr.find_all('td')[1].text
    proxy_ips.append(proxy)
    
print(proxy_ips)
# Out:
# ['110.74.195.215:44975', '136.228.128.164:53052', '36.89.229.13:33389', '92.126.223.237:41258', '186.225.45.13:45974', '109.200.227.36:53281', '202.3.72.50:56242', '182.23.28.186:31064', '109.111.135.28:53281', '175.100.16.20:37725', '165.0.75.137:8080', '185.158.127.9:53281', '186.232.15.9:45849', '188.43.52.166:47362', '45.227.156.105:50013', '124.41.211.153:47411', '176.103.40.198:40039', '177.91.111.233:8080', '142.93.155.127:8118', '189.113.217.35:42517', '123.200.20.242:58847', '179.40.75.1:38736', '194.135.75.74:55716', '36.90.19.227:8181', '159.192.97.181:23500', '91.203.236.226:48975', '103.240.206.196:35101', '191.103.254.125:51869', '103.245.188.86:54385', '181.57.198.102:46960', '166.150.32.184:43539', '221.120.210.211:39617', '180.232.77.107:51480', '89.216.48.230:44061', '200.69.78.91:63141', '198.50.214.17:8585', '164.77.147.93:53281', '202.63.104.89:54297', '181.112.40.114:55314', '46.241.120.230:32412', '45.235.86.1:51996', '118.173.232.215:43186', '24.172.225.122:53281', '119.82.253.24:44060', '115.77.191.180:53281', '191.100.24.251:21776', '103.13.181.15:8080', '95.104.54.227:42119', '80.106.247.145:53410', '46.8.28.17:8080', '102.176.160.70:61279', '138.122.30.14:30097', '103.78.213.226:45075', '109.237.147.213:37581', '36.89.182.225:32917', '120.138.117.102:59308', '170.82.73.140:53281', '27.122.25.8:40205', '80.78.75.59:38253', '213.96.26.70:53855', '36.89.187.193:50689', '212.42.113.240:37545', '1.179.206.161:59033', '200.41.94.121:41310', '36.76.26.40:8080', '185.204.208.78:8080', '101.109.255.97:54623', '94.74.158.83:8080', '213.174.10.58:48691', '81.163.36.210:34197', '118.99.100.162:8080', '3.217.172.234:80', '36.89.194.113:38622', '78.110.154.177:59888', '167.99.164.136:80', '77.46.138.137:52792', '186.248.170.82:53281', '103.6.206.17:53281', '181.143.106.162:39617', '36.66.61.7:56232', '103.36.81.19:49654', '216.198.188.26:51068', '109.167.113.9:59606', '36.89.227.34:55177', '157.245.138.230:8118', '74.59.132.126:49073', '195.158.109.248:59646', '109.122.80.234:44556', '200.54.194.13:53281', '122.102.41.82:55783', '185.64.208.207:53281', '195.182.152.238:38178', '82.113.39.38:33915', '181.168.206.106:38024', '103.225.206.22:31777', '95.65.73.200:43686', '103.221.254.2:40576', '187.73.68.14:53281', '92.114.234.206:46685', '139.255.94.122:44315']

# %%
for i in range(10):
    ip = random.choice(proxy_ips)
    print('Use', ip)
    try:
        resp = requests.get('http://ip.filefab.com/index.php',
                        proxies={'http': ip, 'https': ip}, timeout=10)
        soup = BeautifulSoup(resp.text, 'html5lib')
        print(soup.find('h1', id='ipd').text.strip())
    except:
        print('Fail')
# Out:
# Use 194.135.75.74:55716
# Fail
# Use 1.179.206.161:59033
# Fail
# Use 185.64.208.207:53281
# Your IP address: 185.64.208.207
# Use 191.103.254.125:51869
# Fail
# Use 216.198.188.26:51068
# Fail
# Use 164.77.147.93:53281
# Fail
# Use 181.112.40.114:55314
# Fail
# Use 36.76.26.40:8080
# Fail
# Use 36.76.26.40:8080
# Fail
# Use 36.89.182.225:32917
# Fail
