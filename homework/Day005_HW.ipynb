# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位

#讀取資料
import requests
data=requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response=data.text
response

import json 
data=json.loads(response)
print('一次會回傳',len(data),'筆資料')
print('---')
print('每筆資料包含欄位有',data[0].keys())
# Out:
# 一次會回傳 30 筆資料
# ---
# 每筆資料包含欄位有 dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

import json
data=json.loads(response)
for js in data:
    print('標題',js['title'])
    print('貼文時間',js['createdAt'])
    print('留言人數',js['commentCount'])
    print('按讚人數',js['likeCount'])
# Out:
# 標題 可以不要拉摸ㄎㄧㄤ嗎
# 貼文時間 2019-12-08T03:04:28.277Z
# 留言人數 16
# 按讚人數 642
# 標題 IKEA的鯊魚484有毒
# 貼文時間 2019-12-08T10:11:47.468Z
# 留言人數 11
# 按讚人數 284
# 標題 海水sps缸紀錄📝
# 貼文時間 2019-12-08T01:07:06.659Z
# 留言人數 29
# 按讚人數 184
# 標題 我家的貓根本表情包 ！
# 貼文時間 2019-12-08T03:54:39.812Z
# 留言人數 2
# 按讚人數 57
# 標題 AKA 夢幻狐狸犬
# 貼文時間 2019-12-07T23:35:11.592Z
# 留言人數 4
# 按讚人數 47
# 標題 長的不太一樣
# 貼文時間 2019-12-07T21:32:32.942Z
# 留言人數 1
# 按讚人數 36
# 標題 我家第一隻狐狸寶貝！(๑˃̵ᴗ˂̵)
# 貼文時間 2019-12-08T09:33:48.688Z
# 留言人數 1
# 按讚人數 35
# 標題 嘴上說討厭，身體倒蠻誠實的⁎⁍̴̛ᴗ⁍̴̛⁎
# 貼文時間 2019-12-08T13:22:01.659Z
# 留言人數 8
# 按讚人數 32
# 標題 小貓每次喝水都嗆到 一直發出嗚嗚聲是正常的嗎…
# 貼文時間 2019-12-07T23:22:39.793Z
# 留言人數 1
# 按讚人數 28
# 標題 我家狗狗好像每天都很累
# 貼文時間 2019-12-08T16:43:39.355Z
# 留言人數 2
# 按讚人數 23
# 標題 我的小女兒-嘎逼🐰
# 貼文時間 2019-12-08T10:54:04.444Z
# 留言人數 16
# 按讚人數 23
# 標題 半夜不睡覺的喵ㄦ😂
# 貼文時間 2019-12-08T20:55:38.826Z
# 留言人數 6
# 按讚人數 22
# 標題 我再也不敢給學生領養寵物！！（文長
# 貼文時間 2019-12-09T00:59:23.212Z
# 留言人數 11
# 按讚人數 18
# 標題 #問 台灣領養的到這種貓嗎
# 貼文時間 2019-12-08T06:14:11.207Z
# 留言人數 19
# 按讚人數 16
# 標題 圖片上的貓🐱
# ...

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

comment_sum=0
like_sum=0

for d in data:
    comment_sum+=d['commentCount']
    sum=comment_sum
    
print('熱門文章')
print('平均留言人數:', sum/len(data))

sum=0
for d in data:
    like_sum+=d['likeCount']
    sum=like_sum
print('平均按讚人數:', sum/len(data))
print("")

comment_sum=0
like_sum=0
sum=0

for d in data:
    comment_sum+=d['commentCount']
    sum=comment_sum
    
print('非熱門文章')
print('平均留言人數:', sum/len(data))

sum=0
for d in data:
     like_sum+=d['likeCount']
     sum=like_sum
print('平均按讚人數:', sum/len(data))
# Out:
# 熱門文章
# 平均留言人數: 5.4
# 平均按讚人數: 50.333333333333336
#
# 非熱門文章
# 平均留言人數: 5.4
# 平均按讚人數: 50.333333333333336
